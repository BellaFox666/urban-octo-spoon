# %% [markdown]
# # Data Integration Project: Film Data

# %%
import pandas as pd

# %%
movies           = pd.read_csv("movies.csv")
ratings          = pd.read_csv("ratings.csv")
revenues_per_day = pd.read_csv("revenues_per_day.csv")

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
revenues_per_day
# Out:
#                                           id        date  \
# 0       8b19ad43-3a7e-b14b-49e9-1f7a0eb1568e  2004-09-20
# 1       481fc700-fcdd-1919-c53c-09fcd423a596  2004-09-20
# 2       06719cc2-c05e-8c0b-56b6-b8b13e056509  2004-09-20
# 3       3be8e4a8-2716-00be-80be-eb342ba3cbe7  2004-09-20
# 4       c5f26b59-6a64-ae8e-8f58-7cefb09eadfe  2004-09-20
# ...                                      ...         ...
# 339481  57ced28e-3710-51bb-1213-37c03d3fcfa5  2023-05-06
# 339482  a994197a-10af-0c36-d757-9580f3eee937  2023-05-06
# 339483  70159df5-0b14-2ff5-f2ac-fd737ebbead9  2023-05-06
# 339484  7086d498-528f-03ec-f4c0-9bf013406c3f  2023-05-06
# 339485  451bc2b7-59b5-3971-edcc-0311de528c19  2023-05-06
#
#                                                     title  revenue  theaters  \
# 0                   Sky Captain and the World of Tomorrow   925482    3170.0
# 1                               Resident Evil: Apocalypse   643680    3284.0
# ...
